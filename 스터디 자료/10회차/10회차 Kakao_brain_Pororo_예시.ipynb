# %% [markdown]
# ##Pororo : https://github.com/kakaobrain/pororo

# %%
# !pip install pororo

# %%
# !pip install python-mecab-ko

# %%
from pororo import Pororo

# %% [markdown]
# ##Fill in the Blank

# %%
fib = Pororo(task="fib", lang="ko")
fib("__은 한 천체가 다른 천체 주위를 원이나 타원 궤도를 따라 도는 것을 말한다.")
# Out:
# ['공전',
#  ')',
#  '이것',
#  '다음',
#  '타원',
#  '점성술',
#  '보통',
#  '성운',
#  '자기장',
#  '스핀',
#  '자전',
#  '블랙홀',
#  '운동',
#  '현상']

# %%
fib("화성은 태양계의 네 번째 __이며, 4개의 지구형 행성 중 하나다.")
# Out:
# ['행성', '별', '위성', '지', '주', '자리', '째', '군', '지구', '항성', '달', '천체', '성', '태양계']

# %%
fib = Pororo(task="fib", lang="en")
fib("David Beckham is a famous __ player.")
# Out:
# ['soccer', 'football', 'basketball', 'baseball', 'tennis']

# %% [markdown]
# ##Image Caption

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
caption = Pororo(task="caption", lang="en")
img_url = "https://image.freepik.com/free-photo/group-people-make-selfie-photo-cafe-best-friends-gathered-together-dinner-table-eating-pizza-singing-various-drinks_146671-19854.jpg"
caption(img_url)
# Out:
# ...
# Downloading: "https://github.com/facebookresearch/detr/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# ...
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth" to /root/.cache/torch/hub/checkpoints/detr-r50-e632da11.pth
# ...
# 'A group of people sitting around a table with food.'

# %% [markdown]
# ##Text Summary

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
input_text1 = """스마트기기 공학 전공을 이수한 학생은 스마트폰 연구 및 개발자, 인공지능 시스템 개발자, SW 프로그래머, 시스템 하드웨어 개발자, 네트워크 전문가, IT컨설턴트, 스마트홈/로봇/웨어러블시스템 개발자, 국내외 대학원 및 연구소 등을 비롯한 다양한 진로로 진출이 가능하며, 또한 현 시대가 요구하고 있는 벤처기업 창업을 통해서 성공적인 기업을 일구어낼 수 있는 진로 진출도 가능합니다."""

# %%
abs_summ = Pororo(task="text_summarization", lang="ko", model="abstractive")
abs_summ(input_text1)
# Out:
# ...
# '스마트기기 공학 전공을 이수한 학생은 다양한 진로, 특히 스마트홈/로봇/웨어러블시스템 개발자, 국내외 대학원 및 연구소 등을 비롯한 다양한 진로 진출과 벤처기업 창업을 통한 성공적인 기업을 일구어낼 수 있는 진로 진출이 가능합니다.'
